# %%
import random
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt
import math

class Rectangles
    def __init__(self):
        return None
    def conrect():
    x1 = 0
    x2 = 0
    y1 = 0
    y2 = 0
    self.cr = []
    for i in range(2):
        while (x2 == x1 or y2 == y1):
            x1 = random.randint(0,100)
            x2 = random.randint(0,100)
            y1 = random.randint(0,100)
            y2 = random.randint(0,100)
            if (x2 != x1 or y2 != y1):
                if (x1 > x2):
                    a = x1
                    x1 = x2
                    x2 = a
                if (y1 > y2):
                    a = y1
                    y1 = y2
                    y2 = a
                #cr.append((x1,x2,y1,y2))
                print ("x1 is ", x1)
                print ("y1 is ", y1)
                print ("x2 is ", x2)
                print ("y2 is ", y2) 
                print ("The points are ", "(",x1,",",y1,")", ",", "(",x2,",",y1,")", ",", 
                       "(",x1,",",y2,")", ",", "(",x2,",",y2,")" )
                self.cr.append(x1)
                self.cr.append(y1)
                self.cr.append(x2)
                self.cr.append(y2)
    return self.cr

    def classifypoints(points):
    self.concept = conrect()
    x1 = self.concept[0]
    y1 = self.concept[1]
    x2 = self.concept[2]
    y2 = self.concept[3]
    positive = []
    negative = []
    self.posxs = []
    self.posys = [] 
    negxs = []
    negys = []
    for point in points:
        p1 = point[0]
        p2 = point[1]
        if (p1 >= x1 and p1 <= x2 and p2 >= y1 and p2 <= y2 ):
                positive.append(point)
                self.posxs.append(p1)
                self.posys.append(p2)
        else:
                negative.append(point)
                negxs.append(p1)
                negys.append(p2)
    print ("The positive points are", positive)
    print ("The negative points are", negative)
    return (positive, negative)

    def hyporect():
    #given training examples of length-2
    #labeled according to a concept c
    #returns a consistent hypothesis rectangle h
    self.hr = []
    hx1 = min(self.posxs)
    hx2 = max(self.posxs)
    hy1 = min(self.posys)
    hy2 = max(self.posys)
    hr.append(hx1)
    hr.append(hy1)
    hr.append(hx2)
    hr.append(hy2)
    print (hx1, hy1, hx2, hy2)
    return hr

    def trainingpoints():
    #cr = conrect()
    point = []
    points = []
    positive = []
    negative = []
    while (len(points) != 100):
        p1 = random.randint(0,100)
        p2 = random.randint(0,100)
        point.append(p1)
        point.append(p2)
        while (point not in points):
            points.append(point)
        point = []
    positive, negative = classifypoints(points)
    #classifypoints(points)
    print ("The number of positive points are ", len(positive))
    print ("The number of negative points are ", len(negative))
    return 

    def predict(tsize):
    testpoint = []
    testpoints = []
    while (len(testpoints) != tsize):
        p1 = random.randint(0,100)
        p2 = random.randint(0,100)
        testpoint.append(p1)
        testpoint.append(p2)
        while (point not in points):
            testpoints.append(testpoint)
        testpoint = []
    #Predict the generalization error on these 1000 new examples
    #Need the concept rectangle
    #Need the hypothesis rectangle
    hx1 = min(self.posxs)
    hx2 = max(self.posxs)
    hy1 = min(self.posys)
    hy2 = max(self.posys)
    cx1 = self.concept[0]
    cy1 = self.concept[1]
    cx2 = self.concept[2]
    cy2 = self.concept[3]
    wrongpoint = []
    wrongpoints = []
    for i in testpoints:
        if (((i[0]>cx1 and i[0]<hx1) or (i[0]>hx2 and i[0]<cx2)) and ((i[1]>cy1 and i[1]<hy1) or (i[1]>hy2 and i[1]<cy2)):
            wrongpoint.append(i[0])
            wrongpoint.append(i[1])
            wrongpoints.append(wrongpoint)
    return
